# %%
# PDF -> DOCX (один файл)
# !python -m Office_Tweaks_refactired --pdf2docx "/Users/admin13112025/Desktop/Языки_программирования/6_1.pdf"
# Out:
# [INFO] Start to convert /Users/admin13112025/Desktop/Языки_программирования/6_1.pdf
# [INFO] [1/4] Opening document...
# [INFO] [2/4] Analyzing document...
# [INFO] [3/4] Parsing pages...
# [INFO] (1/3) Page 1
# [INFO] (2/3) Page 2
# [INFO] (3/3) Page 3
# [INFO] [4/4] Creating pages...
# [INFO] (1/3) Page 1
# [INFO] (2/3) Page 2
# [INFO] (3/3) Page 3
# [INFO] Terminated in 0.30s.
# Готово: 6_1.pdf -> 6_1.docx

# %%
# PDF -> DOCX (все файлы в папке)
# !python -m Office_Tweaks_refactired --pdf2docx all --workdir "/Users/admin13112025/Desktop/Языки_программирования"
# Out:
# [INFO] Start to convert /Users/admin13112025/Desktop/Языки_программирования/6_1.pdf
# [INFO] [1/4] Opening document...
# [INFO] [2/4] Analyzing document...
# [INFO] [3/4] Parsing pages...
# [INFO] (1/3) Page 1
# [INFO] (2/3) Page 2
# [INFO] (3/3) Page 3
# [INFO] [4/4] Creating pages...
# [INFO] (1/3) Page 1
# [INFO] (2/3) Page 2
# [INFO] (3/3) Page 3
# [INFO] Terminated in 0.30s.
# Готово: 6_1.pdf -> 6_1.docx
# [INFO] Start to convert /Users/admin13112025/Desktop/Языки_программирования/7.pdf
# [INFO] [1/4] Opening document...
# [INFO] [2/4] Analyzing document...
# [INFO] [3/4] Parsing pages...
# [INFO] (1/2) Page 1
# [INFO] (2/2) Page 2
# [INFO] [4/4] Creating pages...
# [INFO] (1/2) Page 1
# [INFO] (2/2) Page 2
# [INFO] Terminated in 0.37s.
# Готово: 7.pdf -> 7.docx

# %%
# %pip install docx2pdf
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# DOCX -> PDF (один файл)
# !python -m Office_Tweaks_refactired --docx2pdf "/Users/admin13112025/Desktop/Языки_программирования/6_1.docx"
# Out:
#   0%|                                                     | 0/1 [00:04<?, ?it/s]
# Готово: 6_1.docx -> 6_1.pdf

# %%
# Сжатие (один файл)
# !python -m Office_Tweaks_refactired --compress-images "/Users/admin13112025/Desktop/Языки_программирования/photo.jpg" --quality 60
# Out:
# Готово: photo.jpg -> photo_compressed.jpg

# %%
# Сжатие (все в папке)
# !python -m Office_Tweaks_refactired --compress-images all --workdir "/Users/admin13112025/Desktop/Языки_программирования/" --quality 85
# Out:
# Готово: photo.jpg -> photo_compressed.jpg
# Готово: photo_compressed.jpg -> photo_compressed_compressed.jpg

# %%
# !python -m Office_Tweaks_refactired --delete --delete-mode extension --delete-pattern docx --delete-dir "/Users/admin13112025/Desktop/Языки_программирования/"
# Out:
# Файл: "7.docx" успешно удалён!
# Файл: "6_1.docx" успешно удалён!

# %%
# Интерактив
# !python -m Office_Tweaks_refactired -i
# Out:
# Текущий каталог: /Users/admin13112025/Desktop/Языки_программирования
#
# Выберите действие:
# 0. Сменить рабочий каталог
# 1. Преобразовать PDF в Docx
# 2. Преобразовать Docx в PDF
# 3. Произвести сжатие изображений
# 4. Удалить группу файлов
# 5. Выход
# Ваш выбор: ^C
# Traceback (most recent call last):
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/Users/admin13112025/Desktop/Языки_программирования/Office_Tweaks_refactired/__main__.py", line 4, in <module>
#     run_with_args()
#   File "/Users/admin13112025/Desktop/Языки_программирования/Office_Tweaks_refactired/job.py", line 163, in run_with_args
#     run_cli()
#   File "/Users/admin13112025/Desktop/Языки_программирования/Office_Tweaks_refactired/job.py", line 42, in run_cli
#     action = ask_int("Ваш выбор: ", min_value=0, max_value=5)
#   File "/Users/admin13112025/Desktop/Языки_программирования/Office_Tweaks_refactired/utils.py", line 47, in ask_int
# ...
