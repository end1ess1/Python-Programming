# %%
# %pip install pdf2docx Pillow
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from Office_Tweaks.job import run_cli
run_cli()
# Out:
# Текущий каталог: /Users/admin13112025/Desktop/Языки_программирования
#
# Выберите действие:
# 0. Сменить рабочий каталог
# 1. Преобразовать PDF в Docx
# 2. Преобразовать Docx в PDF
# 3. Произвести сжатие изображений
# 4. Удалить группу файлов
# 5. Выход
#
# Список файлов с расширением .pdf в каталоге: /Users/admin13112025/Desktop/Языки_программирования
# 1. 6_1.pdf
# 2. 7.pdf
# [INFO] Start to convert /Users/admin13112025/Desktop/Языки_программирования/6_1.pdf
# [INFO] [1/4] Opening document...
# [INFO] [2/4] Analyzing document...
# [INFO] [3/4] Parsing pages...
# [INFO] (1/3) Page 1
# [INFO] (2/3) Page 2
# [INFO] (3/3) Page 3
# [INFO] [4/4] Creating pages...
# [INFO] (1/3) Page 1
# [INFO] (2/3) Page 2
# [INFO] (3/3) Page 3
# [INFO] Terminated in 0.48s.
# Готово: 6_1.pdf -> 6_1.docx
#
# Текущий каталог: /Users/admin13112025/Desktop/Языки_программирования
#
# Выберите действие:
# 0. Сменить рабочий каталог
# 1. Преобразовать PDF в Docx
# 2. Преобразовать Docx в PDF
# ...
